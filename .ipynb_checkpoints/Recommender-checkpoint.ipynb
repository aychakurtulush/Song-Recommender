# %%
import numpy as np
import pandas as pd
import pickle
import random
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score

# %%
#Load the dataframe into a variable
billboard100 = pd.read_csv('Data/billboards_100.csv')
X = pd.read_csv('Data/top_songs.csv')
X_clustered = pd.read_csv('Data/playlists_clustered.csv')

# %%
billboard100
# Out:
#                            song                                artist
# 0                       Flowers                           Miley Cyrus
# 1                     Kill Bill                                   SZA
# 2                    Last Night                         Morgan Wallen
# 3                        Unholy                Sam Smith & Kim Petras
# 4                      Creepin'  Metro Boomin, The Weeknd & 21 Savage
# ..                          ...                                   ...
# 95                   Yandel 150                         Yandel & Feid
# 96               Heart To Heart                           Mac DeMarco
# 97          Next Thing You Know                          Jordan Davis
# 98  Never Gonna Not Dance Again                                  P!nk
# 99                    Open Arms            SZA Featuring Travis Scott
#
# [100 rows x 2 columns]

# %%
import config
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
user_song = str(input('What is your favorite song? '))
# Out:
# What is your favorite song? Hello

# %%
results = sp.search(q = user_song, limit = 3, market="GB")
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Hello&type=track&market=GB&offset=0&limit=3',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#        'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#        'id': '4dpARuHxo51G3z768sgnrY',
#        'name': 'Adele',
#        'type': 'artist',
#        'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6TVfiWmo8KtflUAmkK9gGF'},
#      'href': 'https://api.spotify.com/v1/albums/6TVfiWmo8KtflUAmkK9gGF',
#      'id': '6TVfiWmo8KtflUAmkK9gGF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f1ea3305aa003425dda05882',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f1ea3305aa003425dda05882',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f1ea3305aa003425dda05882',
#        'width': 64}],
#      'name': '25',
#      'release_date': '2015-11-20',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:6TVfiWmo8KtflUAmkK9gGF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#       'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#       'id': '4dpARuHxo51G3z768sgnrY',
#       'name': 'Adele',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#     'disc_number': 1,
#     'duration_ms': 295502,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBKS1500214'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1Yk0cQdMLx5RzzFTYwmuld'},
#     'href': 'https://api.spotify.com/v1/tracks/1Yk0cQdMLx5RzzFTYwmuld',
#     'id': '1Yk0cQdMLx5RzzFTYwmuld',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Hello',
#     'popularity': 71,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ad2689272eaeaa95348dd83c7a8b45ad378dc0a4?cid=7bed403c576146fc9d57f348edafc918',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1Yk0cQdMLx5RzzFTYwmuld'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4bgVMoeAyy3MUAbCGJDQOE'},
#      'href': 'https://api.spotify.com/v1/albums/4bgVMoeAyy3MUAbCGJDQOE',
#      'id': '4bgVMoeAyy3MUAbCGJDQOE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273023dcbf95f0ab607c91ad36a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02023dcbf95f0ab607c91ad36a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851023dcbf95f0ab607c91ad36a',
#        'width': 64}],
#      'name': 'Disfruta La Party Vol. 4',
#      'release_date': '2023-02-15',
#      'release_date_precision': 'day',
#      'total_tracks': 30,
#      'type': 'album',
#      'uri': 'spotify:album:4bgVMoeAyy3MUAbCGJDQOE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#       'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#       'id': '790FomKkXshlbRYZFtlgla',
#       'name': 'KAROL G',
#       'type': 'artist',
#       'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1i8SpTcr7yvPOmcqrbnVXY'},
#       'href': 'https://api.spotify.com/v1/artists/1i8SpTcr7yvPOmcqrbnVXY',
#       'id': '1i8SpTcr7yvPOmcqrbnVXY',
#       'name': 'Ozuna',
#       'type': 'artist',
#       'uri': 'spotify:artist:1i8SpTcr7yvPOmcqrbnVXY'}],
#     'disc_number': 1,
#     'duration_ms': 194933,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71610032'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6ZAs7HwTfbKkIWryZyXjW5'},
#     'href': 'https://api.spotify.com/v1/tracks/6ZAs7HwTfbKkIWryZyXjW5',
#     'id': '6ZAs7HwTfbKkIWryZyXjW5',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Hello',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d051e95157dc63f7ef4e60a131a27677b215f4d4?cid=7bed403c576146fc9d57f348edafc918',
#     'track_number': 24,
#     'type': 'track',
#     'uri': 'spotify:track:6ZAs7HwTfbKkIWryZyXjW5'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UdoKjWIe3tHyiqc4qT3Oz'},
#        'href': 'https://api.spotify.com/v1/artists/0UdoKjWIe3tHyiqc4qT3Oz',
#        'id': '0UdoKjWIe3tHyiqc4qT3Oz',
#        'name': 'OMFG',
#        'type': 'artist',
#        'uri': 'spotify:artist:0UdoKjWIe3tHyiqc4qT3Oz'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7lZoV4KNsiutw9uTkbZwnA'},
#      'href': 'https://api.spotify.com/v1/albums/7lZoV4KNsiutw9uTkbZwnA',
#      'id': '7lZoV4KNsiutw9uTkbZwnA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273417bebe37c4c4c2430036143',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02417bebe37c4c4c2430036143',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851417bebe37c4c4c2430036143',
#        'width': 64}],
#      'name': 'Hello',
#      'release_date': '2014-12-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7lZoV4KNsiutw9uTkbZwnA'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UdoKjWIe3tHyiqc4qT3Oz'},
#       'href': 'https://api.spotify.com/v1/artists/0UdoKjWIe3tHyiqc4qT3Oz',
#       'id': '0UdoKjWIe3tHyiqc4qT3Oz',
#       'name': 'OMFG',
#       'type': 'artist',
#       'uri': 'spotify:artist:0UdoKjWIe3tHyiqc4qT3Oz'}],
#     'disc_number': 1,
#     'duration_ms': 226307,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCACC1430912'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6BAnxKyld909yo6Pk1DO3r'},
#     'href': 'https://api.spotify.com/v1/tracks/6BAnxKyld909yo6Pk1DO3r',
#     'id': '6BAnxKyld909yo6Pk1DO3r',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Hello',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c6e84079e460c28e57450b01fffdf4b033a82a17?cid=7bed403c576146fc9d57f348edafc918',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6BAnxKyld909yo6Pk1DO3r'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=Hello&type=track&market=GB&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 1000}}

# %%
#Find artist
user_artist = results['tracks']['items'][0]['artists'][0]['name']

#Track ID
user_id = results['tracks']['items'][0]['id']

#Audio features
user_features = sp.audio_features(tracks=[user_id])

# %%
user_song_df = pd.DataFrame(user_features)
user_song_df = user_song_df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo"]]
user_song_df
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.578    0.43    -6.134       0.0305          0.33
#
#    instrumentalness  liveness  valence   tempo
# 0                 0    0.0854    0.288  78.991

# %%
X = pd.DataFrame(X, columns= ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo'])

print()
X.head()
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.514   0.730    -5.934       0.0598       0.00146
# 1         0.707   0.681    -4.325       0.0668       0.06320
# 2         0.644   0.735    -5.747       0.0391       0.05210
# 3         0.715   0.620    -6.005       0.0484       0.41700
# 4         0.440   0.317    -9.258       0.0531       0.89100
#
#    instrumentalness  liveness  valence    tempo
# 0          0.000095    0.0897    0.334  171.005
# 1          0.000005    0.0322    0.646  117.999
# 2          0.144000    0.1610    0.418   88.980
# 3          0.000000    0.0822    0.172   97.950
# 4          0.000005    0.1410    0.268  169.914

# %%
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns = X.columns)
display(X.head())
print()
display(X_scaled_df.head())
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.514   0.730    -5.934       0.0598       0.00146
# 1         0.707   0.681    -4.325       0.0668       0.06320
# 2         0.644   0.735    -5.747       0.0391       0.05210
# 3         0.715   0.620    -6.005       0.0484       0.41700
# 4         0.440   0.317    -9.258       0.0531       0.89100
#
#    instrumentalness  liveness  valence    tempo
# 0          0.000095    0.0897    0.334  171.005
# 1          0.000005    0.0322    0.646  117.999
# 2          0.144000    0.1610    0.418   88.980
# 3          0.000000    0.0822    0.172   97.950
# 4          0.000005    0.1410    0.268  169.914
#    danceability    energy  loudness  speechiness  acousticness  \
# 0     -0.951795  0.415223  0.481467    -0.191236     -0.895051
# 1      0.389657  0.150565  0.948845    -0.094941     -0.628441
# 2     -0.048226  0.442229  0.535786    -0.475992     -0.676374
# 3      0.445261 -0.178909  0.460843    -0.348058      0.899362
# 4     -1.466134 -1.815472 -0.484080    -0.283403      2.946220
#
#    instrumentalness  liveness   valence     tempo
# 0         -0.235272 -0.583126 -0.997710  1.827186
# 1         -0.236089 -1.020810  0.271709 -0.119582
# 2          1.067969 -0.040398 -0.655944 -1.185372
# 3         -0.236136 -0.640215 -1.656832 -0.855928
# 4         -0.236093 -0.192636 -1.266241  1.787116

# %%
kmeans = KMeans(n_clusters = 7, random_state = 1234)
kmeans.fit(X_scaled_df)
# Out:
# KMeans(n_clusters=7, random_state=1234)

# %%
kmeans.labels_
X
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.514   0.730    -5.934       0.0598       0.00146
# 1           0.707   0.681    -4.325       0.0668       0.06320
# 2           0.644   0.735    -5.747       0.0391       0.05210
# 3           0.715   0.620    -6.005       0.0484       0.41700
# 4           0.440   0.317    -9.258       0.0531       0.89100
# ..            ...     ...       ...          ...           ...
# 548         0.692   0.525   -12.691       0.0373       0.02120
# 549         0.712   0.640   -14.215       0.0321       0.01110
# 550         0.716   0.860    -7.807       0.0460       0.00917
# 551         0.524   0.330   -14.264       0.0297       0.65400
# 552         0.641   0.888    -5.213       0.0364       0.14400
#
#      instrumentalness  liveness  valence    tempo
# 0            0.000095    0.0897   0.3340  171.005
# 1            0.000005    0.0322   0.6460  117.999
# 2            0.144000    0.1610   0.4180   88.980
# 3            0.000000    0.0822   0.1720   97.950
# 4            0.000005    0.1410   0.2680  169.914
# ..                ...       ...      ...      ...
# 548          0.001900    0.0944   0.0879  103.679
# 549          0.047800    0.0638   0.9250  130.259
# 550          0.839000    0.2510   0.9580  142.168
# 551          0.000000    0.0635   0.5530  179.598
# 552          0.000000    0.3470   0.9580  144.786
#
# [553 rows x 9 columns]

# %%
user_scaled = scaler.transform(user_song_df)
user_scaled_df = pd.DataFrame(user_scaled, columns = user_song_df.columns)
user_scaled_df
# Out:
#    danceability    energy  loudness  speechiness  acousticness  \
# 0     -0.506961 -1.205136  0.423372    -0.594296      0.523673
#
#    instrumentalness  liveness   valence     tempo
# 0         -0.236136 -0.615857 -1.184868 -1.552241

# %%
# Get the cluster label of user song
user_cluster = kmeans.predict(user_scaled_df)

user_cluster_num = user_cluster[0]

# %%
X_clustered = pd.read_csv('data/playlists_clustered.csv')

# %%
X_clustered
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.514   0.730    -5.934       0.0598       0.00146
# 1           0.707   0.681    -4.325       0.0668       0.06320
# 2           0.644   0.735    -5.747       0.0391       0.05210
# 3           0.715   0.620    -6.005       0.0484       0.41700
# 4           0.440   0.317    -9.258       0.0531       0.89100
# ..            ...     ...       ...          ...           ...
# 548         0.692   0.525   -12.691       0.0373       0.02120
# 549         0.712   0.640   -14.215       0.0321       0.01110
# 550         0.716   0.860    -7.807       0.0460       0.00917
# 551         0.524   0.330   -14.264       0.0297       0.65400
# 552         0.641   0.888    -5.213       0.0364       0.14400
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.000095    0.0897   0.3340  171.005  0VjIjW4GlUZAMYd2vXMi3b
# 1            0.000005    0.0322   0.6460  117.999  0yLdNVWF3Srea0uzk55zFn
# 2            0.144000    0.1610   0.4180   88.980  1Qrg8KqiBpW07V7PNxwwwL
# 3            0.000000    0.0822   0.1720   97.950  2dHHgzDwk4BJdRwy9uXhTO
# 4            0.000005    0.1410   0.2680  169.914  6xGruZOHLs39ZbVccQTuPZ
# ..                ...       ...      ...      ...                     ...
# 548          0.001900    0.0944   0.0879  103.679  0vZCwj0Mq5uS8GwSIYo6Y7
# 549          0.047800    0.0638   0.9250  130.259  1PuUboooNpZFmtsCJRF4sn
# 550          0.839000    0.2510   0.9580  142.168  2CfqGS6D9piBWM3SAjbUJM
# 551          0.000000    0.0635   0.5530  179.598  7mZBgeTb3oLqTRwC1suWXN
# 552          0.000000    0.3470   0.9580  144.786  5j4RaTG3kjLlreau6KjLrf
#
#      duration_ms          artist                                    name  \
# 0         200040      The Weeknd                         Blinding Lights
# 1         200455     Miley Cyrus                                 Flowers
# 2         153947             SZA                               Kill Bill
# 3         221520    Metro Boomin  Creepin' (with The Weeknd & 21 Savage)
# 4         233456            Joji                           Glimpse of Us
# ..           ...             ...                                     ...
# 548       333200     Rod Stewart                                 Passion
# 549       252067     Liquid Gold                    Dance Yourself Dizzy
# 550       201013  Spandau Ballet               To Cut A Long Story Short
# 551       255000  Peaches & Herb                        I Pledge My Love
# 552       166760         Madness                          Baggy Trousers
#
#                                  album  popularity  cluster
# 0                          After Hours          87        5
# 1                              Flowers         100        2
# 2                                  SOS          91        2
# 3                    HEROES & VILLAINS          93        4
# 4                        Glimpse of Us          84        3
# ..                                 ...         ...      ...
# 548                  Foolish Behaviour          39        4
# 549                        Liquid Gold          39        4
# 550  Gold - The Best of Spandau Ballet          38        6
# 551                      At Their Best          35        3
# 552                         Absolutely          54        1
#
# [553 rows x 16 columns]

# %%
df = X_clustered[X_clustered['cluster'] == user_cluster_num]

# %%
df
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 3           0.715   0.620    -6.005       0.0484       0.41700
# 5           0.702   0.586    -7.830       0.0313       0.03880
# 8           0.830   0.585    -6.476       0.0940       0.23700
# 20          0.733   0.436   -10.489       0.0800       0.25800
# 25          0.824   0.453    -9.604       0.0968       0.14600
# ..            ...     ...       ...          ...           ...
# 538         0.749   0.668    -9.507       0.0437       0.36400
# 544         0.814   0.612   -13.842       0.0852       0.09310
# 546         0.774   0.596   -14.093       0.0531       0.00192
# 548         0.692   0.525   -12.691       0.0373       0.02120
# 549         0.712   0.640   -14.215       0.0321       0.01110
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 3            0.000000    0.0822   0.1720   97.950  2dHHgzDwk4BJdRwy9uXhTO
# 5            0.000073    0.1560   0.6080  134.951  0mL82sxCRjrs3br407IdJh
# 8            0.000000    0.2480   0.4850  109.978  6Im9k8u9iIzKMrmV7BWtlF
# 20           0.000573    0.1570   0.0976   96.985  5jQI2r1RdgtuT8S3iG8zFC
# 25           0.027300    0.0896   0.5520  119.959  34ZAzO78a5DAVNrYIGWcPm
# ..                ...       ...      ...      ...                     ...
# 538          0.000046    0.0367   0.9250  102.451  4V2cR7mSEDaRa7DXiZMN7o
# 544          0.014900    0.0571   0.6810  127.371  5lm46pyP9yPmoAJnHjgXuW
# 546          0.099800    0.0574   0.5110  136.794  1kIrVGnCuXHTsEpkftL2NT
# 548          0.001900    0.0944   0.0879  103.679  0vZCwj0Mq5uS8GwSIYo6Y7
# 549          0.047800    0.0638   0.9250  130.259  1PuUboooNpZFmtsCJRF4sn
#
#      duration_ms         artist                                       name  \
# 3         221520   Metro Boomin     Creepin' (with The Weeknd & 21 Savage)
# 5         199111     The Weeknd                     Is There Someone Else?
# 8         173711  Ariana Grande                                      34+35
# 20        202396   Taylor Swift                              Lavender Haze
# 25        181831            SZA                                      Shirt
# ..           ...            ...                                        ...
# 538       211360       Dr. Hook                                  Sexy Eyes
# 544       184747        Odyssey  Use It Up and Wear It Out - Radio Version
# 546       275027           UB40                                       King
# 548       333200    Rod Stewart                                    Passion
# 549       252067    Liquid Gold                       Dance Yourself Dizzy
#
#                          album  popularity  cluster
# 3            HEROES & VILLAINS          93        4
# 5                      Dawn FM          81        4
# 8                    Positions          76        4
# 20                   Midnights          85        4
# 25                       Shirt          79        4
# ..                         ...         ...      ...
# 538          Sometimes You Win          46        4
# 544  Use It Up and Wear It Out          42        4
# 546                Signing Off          40        4
# 548          Foolish Behaviour          39        4
# 549                Liquid Gold          39        4
#
# [99 rows x 16 columns]

# %%
joined = pd.merge(df, X)

# %%
joined
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.715   0.620    -6.005       0.0484       0.41700
# 1          0.702   0.586    -7.830       0.0313       0.03880
# 2          0.830   0.585    -6.476       0.0940       0.23700
# 3          0.733   0.436   -10.489       0.0800       0.25800
# 4          0.824   0.453    -9.604       0.0968       0.14600
# ..           ...     ...       ...          ...           ...
# 94         0.749   0.668    -9.507       0.0437       0.36400
# 95         0.814   0.612   -13.842       0.0852       0.09310
# 96         0.774   0.596   -14.093       0.0531       0.00192
# 97         0.692   0.525   -12.691       0.0373       0.02120
# 98         0.712   0.640   -14.215       0.0321       0.01110
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.000000    0.0822   0.1720   97.950  2dHHgzDwk4BJdRwy9uXhTO
# 1           0.000073    0.1560   0.6080  134.951  0mL82sxCRjrs3br407IdJh
# 2           0.000000    0.2480   0.4850  109.978  6Im9k8u9iIzKMrmV7BWtlF
# 3           0.000573    0.1570   0.0976   96.985  5jQI2r1RdgtuT8S3iG8zFC
# 4           0.027300    0.0896   0.5520  119.959  34ZAzO78a5DAVNrYIGWcPm
# ..               ...       ...      ...      ...                     ...
# 94          0.000046    0.0367   0.9250  102.451  4V2cR7mSEDaRa7DXiZMN7o
# 95          0.014900    0.0571   0.6810  127.371  5lm46pyP9yPmoAJnHjgXuW
# 96          0.099800    0.0574   0.5110  136.794  1kIrVGnCuXHTsEpkftL2NT
# 97          0.001900    0.0944   0.0879  103.679  0vZCwj0Mq5uS8GwSIYo6Y7
# 98          0.047800    0.0638   0.9250  130.259  1PuUboooNpZFmtsCJRF4sn
#
#     duration_ms         artist                                       name  \
# 0        221520   Metro Boomin     Creepin' (with The Weeknd & 21 Savage)
# 1        199111     The Weeknd                     Is There Someone Else?
# 2        173711  Ariana Grande                                      34+35
# 3        202396   Taylor Swift                              Lavender Haze
# 4        181831            SZA                                      Shirt
# ..          ...            ...                                        ...
# 94       211360       Dr. Hook                                  Sexy Eyes
# 95       184747        Odyssey  Use It Up and Wear It Out - Radio Version
# 96       275027           UB40                                       King
# 97       333200    Rod Stewart                                    Passion
# 98       252067    Liquid Gold                       Dance Yourself Dizzy
#
#                         album  popularity  cluster
# 0           HEROES & VILLAINS          93        4
# 1                     Dawn FM          81        4
# 2                   Positions          76        4
# 3                   Midnights          85        4
# 4                       Shirt          79        4
# ..                        ...         ...      ...
# 94          Sometimes You Win          46        4
# 95  Use It Up and Wear It Out          42        4
# 96                Signing Off          40        4
# 97          Foolish Behaviour          39        4
# 98                Liquid Gold          39        4
#
# [99 rows x 16 columns]

# %%
def recommender():
    random_row = []
    if user_song in billboard100['song'].values:
        random_row = billboard100.sample(n=1)
        print('Your favrite song is at top 100 right now, I recommend you to check this hot song as well: ')
        print(random_row['song'] + ' by ' + random_row['artist'])
    else:
        random_song = df.sample(n=1)
        random_row = joined.sample(n=1)
        x = random_row['id']
        print('Here is my recommendation for you based on your taste: ')
        print('open.spotify.com/track/' + x)

# %%
recommender()
# Out:
# Here is my recommendation for you based on your taste:
# 87    open.spotify.com/track/5rc28C9Ym7zIAypx3QGcnv
# Name: id, dtype: object
